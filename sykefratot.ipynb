# %% [markdown]
# # Sjekke ut pakken Sykefravær og sesongjustering

# %% [markdown]
# I denne notebooken har jeg bare testet litt for å se på sykefravær og sesongjusterte tall og sjekket litt for å få mer forståelse av de ulike funksjonene i RDemetra.

# %%
library(PxWebApiData)
library(RJDemetra)

# %%
innData  <- ApiData(12439, Kjonn = "0", Sykefraver2 = "Alt", ContentsCode = "SykefravProsent", Tid = TRUE)
ujustert <- ts(innData$dataset$value, freq = 4, start = c(2000, 2)) ## Serien starter først 2. kvartal!

# %%
ujustert
# Out:
#      Qtr1 Qtr2 Qtr3 Qtr4
# 2000      6.6  5.8  6.9
# 2001 7.5  6.7  6.1  7.2
# 2002 7.8  7.0  6.3  7.7
# 2003 8.0  7.5  6.7  8.2
# 2004 8.0  6.9  5.3  6.2
# 2005 6.8  6.1  5.3  6.5
# 2006 7.3  6.3  5.5  6.5
# 2007 7.2  6.1  5.5  6.6
# 2008 7.1  6.5  5.6  6.8
# 2009 7.4  6.7  6.2  7.1
# 2010 6.7  6.1  5.4  6.7
# 2011 7.1  6.1  5.1  6.2
# 2012 6.7  5.7  5.0  6.3
# 2013 6.9  5.8  4.9  6.0
# 2014 6.5  5.7  5.0  6.0
# 2015 6.6  5.6  4.9  5.9
# 2016 6.3  5.5  4.8  6.3
# 2017 6.6  5.7  4.9  6.1
# 2018 6.8  5.4  4.7  5.9
# 2019 6.5  5.5  4.8  6.1
# 2020 7.2  5.6  5.1  6.3
# 2021 6.5  5.9  5.3  7.0
# 2022 8.3  6.3  5.4

# %%
x13_model <- x13(ujustert)

# %%
x13_model
# Out:
# RegARIMA
# y = regression model + arima (0, 1, 1, 0, 1, 1)
# Log-transformation: yes
# Coefficients:
#           Estimate Std. Error
# Theta(1)   -0.3511      0.108
# BTheta(1)  -0.5867      0.107
#
#               Estimate Std. Error
# LS (III-2004)  -0.1656      0.027
# LS (I-2010)    -0.1348      0.027
# TC (I-2021)    -0.1405      0.026
# LS (I-2004)    -0.1070      0.027
#
#
# Residual standard error: 0.03136 on 78 degrees of freedom
# Log likelihood = 172.8, aic = -21.36 aicc = -19.91, bic(corrected for length) = -6.611
#
#
#
# Decomposition
#  Monitoring and Quality Assessment Statistics:
#       M stats
# M(1)    0.039
# M(2)    0.047
# M(3)    0.676
# M(4)    0.817
# M(5)    0.659
# M(6)    0.325
# M(7)    0.117
# M(8)    0.241
# M(9)    0.197
# M(10)   0.518
# M(11)   0.518
# Q       0.340
# Q-M2    0.376
#
# Final filters:
# Seasonal filter:  3x5
# Trend filter:  5 terms Henderson moving average
#
#
# Final
# Last observed values
#           y       sa        t         s         i
# 2021 Q4 7.0 6.781986 6.818852 1.0321460 0.9945935
# 2022 Q1 8.3 6.914158 6.857914 1.2004353 1.0082014
# 2022 Q2 6.3 6.630121 6.692573 0.9502089 0.9906685
# 2022 Q3 5.4 6.620035 6.638785 0.8157057 0.9971757
#
# Forecasts:
#              y_f     sa_f      t_f       s_f       i_f
# 2022 Q4 6.992818 6.778037 6.735661 1.0316879 1.0062912
# 2023 Q1 8.141356 6.760631 6.779518 1.2042303 0.9972140
# 2023 Q2 6.459093 6.807788 6.816400 0.9487800 0.9987366
# 2023 Q3 5.620935 6.904476 6.895392 0.8141001 1.0013175
#
#
# Diagnostics
#  Relative contribution of the components to the stationary
#  portion of the variance in the original series,
#  after the removal of the long term trend
#  Trend computed by Hodrick-Prescott filter (cycle length = 8.0 years)
#            Component
#  Cycle         1.442
#  Seasonal     33.484
#  Irregular     0.369
#  TD & Hol.     0.000
#  Others       67.311
#  Total       102.607
#
#  Combined test in the entire series
#  Non parametric tests for stable seasonality
#                                                           P.value
#    Kruskall-Wallis test                                          0
#    Test for the presence of seasonality assuming stability       0
#    Evolutive seasonality test                                    0
#
#  Identifiable seasonality present
#
#  Residual seasonality tests
#                                       P.value
#  qs test on sa                          1.000
#  qs test on i                           1.000
#  f-test on sa (seasonal dummies)        0.619
#  f-test on i (seasonal dummies)         0.374
#  Residual seasonality (entire series)   0.616
#  Residual seasonality (last 3 years)    0.461
#  f-test on sa (td)                      0.648
#  f-test on i (td)                       0.329
#
#
# Additional output variables

# %%
plot(x13_model, type_chart = c("sa-trend", "cal-seas-irr"))
plot(x13_model$regarima, which = 7)
plot(x13_model$decomposition)
plot(x13_model$regarima)
# Out:
# Plot with title âY, Sa, trendâ
# Plot with title âCal., sea., irr.â
# Plot with title ââ
# plot without title
# plot without title
# Plot with title ââ
# Plot with title ââ
# Plot with title ââ
# Plot with title ââ
# plot without title
